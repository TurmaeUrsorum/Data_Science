# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
movie_data = pd.read_csv("/home/brilly/myskill_or_anything/Data_Science/11. Project: Understanding Data for Movie Analysis/movies_metadata.csv")
movie_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
# ...

# %%
movie_data.count()
# Out:
# adult                    45463
# belongs_to_collection     4491
# budget                   45463
# genres                   45463
# homepage                  7779
# id                       45463
# imdb_id                  45446
# original_language        45452
# original_title           45463
# overview                 44509
# popularity               45460
# poster_path              45077
# production_companies     45460
# production_countries     45460
# release_date             45376
# revenue                  45460
# runtime                  45203
# spoken_languages         45460
# status                   45379
# tagline                  20412
# title                    45460
# video                    45463
# vote_average             45460
# vote_count               45460
# dtype: int64

# %%
total_data = len(movie_data)
invalid_total = movie_data.columns[movie_data.count() < total_data].tolist()
print(invalid_total)
# Out:
# ['belongs_to_collection', 'homepage', 'imdb_id', 'original_language', 'overview', 'popularity', 'poster_path', 'production_companies', 'production_countries', 'release_date', 'revenue', 'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'vote_average', 'vote_count']

# %%
movie_data.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movie_data.shape
# Out:
# (45463, 24)

# %%
# ngambil 10 data random
movie_data.sample(10)
# Out:
#        adult                              belongs_to_collection    budget  \
# 2532    True  {'id': 218406, 'name': 'Frankenstein (Universa...         0
# 1751    True                                                NaN         0
# 12963   True                                                NaN         0
# 23583   True                                                NaN         0
# 4001    True                                                NaN         0
# 7338    True                                                NaN         0
# 29650   True                                                NaN         0
# 8088    True  {'id': 12263, 'name': 'The Exorcist Collection...  80000000
# 8243    True                                                NaN  25000000
# 21759   True                                                NaN         0
#
#                                                   genres  \
# 2532   [{'id': 14, 'name': 'Fantasy'}, {'id': 27, 'na...
# ...

# %%
movie_data.loc(:, [[]])
